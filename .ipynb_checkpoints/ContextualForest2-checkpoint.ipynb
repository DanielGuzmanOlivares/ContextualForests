# %% [markdown]
# # Contextual Forests V2

# %% [markdown]
# ### 1. BabelNet Iinterface

# %%
import requests
import json
import wikipediaapi
from socket import timeout
from requests.exceptions import ConnectionError
#GLOBAL VARIABLES
wiki = wikipediaapi.Wikipedia('en')
KEY  = 'b361cac5-2b53-40a8-8df8-6a2cfb140491' #Register in BabelNet to get one
BASE = 'https://babelnet.io/v5'
API = {
    "get_info": "getSynset",
    "get_synsets":"getSynsetIds",
    "get_relations":"getOutgoingEdges"
}

def __format_arguments(args):
    """
    Desc: Returns a formatted string for making an HTML request
    Params: - args (dict): dictionary for params values, format is {paramName:paramValue ...}
    Returns: (String) formatted string
    """
    return "&".join(["{}={}".format(key,value) for key,value in args.items()])

def __make_request(args,op,verbose=False):
    """
    Desc: Makes arequest to BabelNet API given a parametters dictionary
    Params: - args (dict): dictionary for params values, format is {paramName:paramValue ...}
            - op (string): operation, choose between {get_info,get_synsets,get_relations}
            - verbose (bool): show messages 
    Returns: (Dict) BabelNet's API response
    """
    args["key"] = KEY
    args["targetLang"] = "EN"
    r = requests.get("{}/{}?{}".format(BASE,API[op],__format_arguments(args)))
    if verbose:
        print("Status code: {}".format(r.status_code))
    return r.json() if r.ok else None

def synset_info(synset_id,verbose=False):
    """
    Desc: Returns the information associated with a BabelNet synset
    Params: - synset_id (String): BabelNet synset id
            - verbose (bool): show messages 
    Returns: (Dict) BabelNet's sysnset information
    """
    return __make_request({"id":synset_id},"get_info",verbose)

def synset_relations(synset_id,verbose=False):
    """
    Desc: Returns the outgoing semantic relations of a synset
    Params: - synset_id (String): BabelNet synset id
            - verbose (bool): show messages 
    Returns: (Dict) BabelNet's sysnset outgoing conexions
    """
    try:
        return __make_request({"id":synset_id},"get_relations",verbose)
    except (ConnectionError,timeout):
        return []

def general_categories(synset_id):
    """  
    Desc: Returns the ids of the general categories a synset belongs to
    Params: - synset_id (String): BabelNet synset id
    Returns: (List)[String] ids 
    """
    try:
        categories = [relation["target"] for relation in synset_relations(synset_id) 
                  if relation["pointer"]["shortName"] in ["is-a","part_of","subclass_of"]]
        res = []
        for cat in categories:
            try:
                #res.append(synset_info(cat)["senses"][0]["properties"]["fullLemma"])
                res.append(synset_info(cat)["senses"][0]["properties"]["synsetID"]["id"] )
            except IndexError:
                continue
        return set(res)
    except (ConnectionError,timeout):
        return []

def wiki_page(synset_id):
    """  
    Desc: Return the wikipedia page associated with a synset id
    Params: - synset_id (String): BabelNet synset id
    Returns: (Wikipediaapi.Page) wikipedia page object
    """
    try:
        synset = synset_info(synset_id)
        for sense in synset["senses"]:
            if sense['properties']["source"] == "WIKI":
                return wiki.page(sense['properties']["fullLemma"].replace("_"," "))
            else:
                continue
        return None
    except (ConnectionError,timeout):
        return None

def search_synsets(lemma,pos,searchLang="EN",verbose=False):
    """  
    Desc: Returns the ids of possible synsets associated to the provided word
    Params: - lemma (String): word for searching
            - pos (String): position (NOUN,VERB ...)
            - searchLang (String): language for search and results
            - verbose (bool): show messages 
    Returns: (List)[String]: ids 
    """
    args = {
        "lemma":lemma,
        "pos":pos,
        "searchLang":searchLang,
        "key":KEY
    }
    return [ele["id"] for ele in __make_request(args,"get_synsets",verbose)]


#search_synsets("apple","NOUN")   
#general_categories("bn:17306106n")
#wiki_page("bn:00289737n").text
#synset_info("bn:03094945n")["domains"]

# %% [markdown]
# ### Wikipedia Interface

# %%
import spacy
import en_core_web_lg
from nltk.stem.porter import *
from more_itertools import locate
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.porter import PorterStemmer
import string
import numpy as np
from scipy.optimize import curve_fit
from nltk.stem import WordNetLemmatizer 

stemmer = SnowballStemmer(language='english')
lemmatizer = WordNetLemmatizer() 
nlp = en_core_web_lg.load()
STOPWORDS = "stopwords.txt" #stopwords_file
with open(STOPWORDS ) as file:
        stop_words = [x.strip() for x in file.readlines()]

# %%
def average_sentence_size(text):
    """Returns the average sentence size"""
    return np.mean([len(sentence.split()) for sentence in text.split(".")])

def clean_text(text):
    """Cleans the text, punctuation marks (. , \n) will be replaced by blank spaces 
    and possessive forms ('es , 's) will be removed. 
    Any other punctuation symbol will also be removed.
    @Params:
        -text: to be cleaned
    @Returns:
        Cleaned text
    """
    text = text.replace("\n"," ").replace(","," ").replace("."," ")
    text = text.replace("'s","").replace("'es","")
    text = text.translate(str.maketrans('', '', string.punctuation))
    return text

def stem_text(text,title=""):
    #pendiente hacerlo mas elegante
    """
    Uses snowball stemmer to produce a dictionary with entries:
        dic = { ...,key:(words,occurr,relevance),... }
    Where words -> list of ocurrences of key in text (page's text)
          occur -> indexes of (key) occurrences in the text
          relevance -> set to 0 (see set_relevance())
    Note that every key = (STEMMED WORD,WORD_POS (Part Of Speech))
    @Params:
        - text: text to be processed
    @Returns:
        (stem_dictionary,cleaned text length)
    """
    dic = {}
    content = clean_text(text).split() #split spaces
    count = 0
    for i,x in enumerate(nlp(clean_text(text))):
        if x.pos_ not in ["NOUN","PROPN","VERB","ADJ"]:
            continue
        try:
            int(x)
            continue
        except:
            if x.text.lower() not in stop_words and "wikipedia" not in x.text.lower() and title not in x.text.lower() :
                stemmed = stemmer.stem(x.text.lower())
                key = (stemmed,x.pos_)
                if key not in dic:
                    dic[key] = {"words":set([x.text.lower()]),"occurr":[i],"relevance":.0,"pos":0}
                else:
                    dic[key]["words"].add(x.text.lower())
                    dic[key]["occurr"].append(i)
        count += 1
    return dic,len(content),text




def relevance(word,text_len,chunk_size=100): #AQUI TENEMOS EL CUELLO DE BOTELLA
    """
    Returns word relevance (probability of being in a randomly 
    positioned block of a fixed size).
    @Params:
        - word:  entry of stem_dict
        - text_len: text size (returned by stem_text())
        - chunk_size: block size, fixed
    """
    L = []
    for i in range(chunk_size,text_len,1):
        added = False
        for occ in word["occurr"]:
            if occ > i - chunk_size and occ <= i:
                L.append(1)
                added = True
                break
        if not added:
                L.append(0)
    #print("SUMA",np.sum(L),"LOng",len(L))
    return np.mean(L)    
    
def set_relevance(stem_dict,text_len,text,sort=False):
    relevances = []
    if text_len < 100: #no aceptamos artículos de menos de 300 palabras
        return None
    else:
        t1 = time()
        n_chunks = int(text_len/average_sentence_size(text)) #por ejemplo, mirar otras posibilidades dinamicas etc...
        for word in stem_dict:
            res = relevance(stem_dict[word],text_len,n_chunks)
            stem_dict[word]["relevance"] = res
        t2 = time()
    if sort:
        t3 = time()
        keys = sorted(stem_dict.keys(),key=lambda k:stem_dict[k]["relevance"], reverse=True)
        for i,key in enumerate(keys):
            stem_dict[key]["pos"] = i
        t4 = time()
   # print("1"+"#"*50,t2-t1)
   # print("2"+"#"*50,t4-t3)
    return stem_dict


def fit_model(stem_dict):
    y_data = []
    if stem_dict == None: #articulo demasiado corto
        return None,None
    keys = sorted(stem_dict.keys(),key=lambda k:stem_dict[k]["relevance"], reverse=True)
    for i,key in enumerate(keys):
        stem_dict[key]["pos"] = i
        y_data.append(stem_dict[key]["relevance"])
    y_data = np.array(y_data)[y_data != 0][0] 
    x_data = np.linspace(1,len(y_data),len(y_data))
    def zipf(x,alpha): #distribucion de Zipf
        return stem_dict[keys[0]]["relevance"]/x**alpha

    popt, pcov = curve_fit(zipf,x_data,y_data)
    return lambda x: zipf(x,popt),stem_dict

def link_relevance(link,stem_dict,model):
        words = nlp(link)
        rel = []
        if ":" in link:
            return 0
        for word in words:
            try:
                pos =  stem_dict[(stemmer.stem(word.text.lower()),word.pos_)]["pos"]
                rel.append(pos)
            except KeyError:
                rel.append(len(stem_dict))
        return model(np.mean(rel))[0] if  len(rel) * sum(rel)  != 0  else 0      

def relevant_links(page,top):
    
    stem_dict = set_relevance(*stem_text(page.text,title=page.title))
    model,stem_dict = fit_model(stem_dict)
    if model is None:
        return []
    return sorted(page.links.items(),key=lambda it: link_relevance(it[0],stem_dict,model),reverse=True)[:top]


#relevant_links(wiki.page("Apple Inc."),10)

# %% [markdown]
# ### From terms to targetted texts

# %%
def generalization(synset_id,top,l=[],level=1):
    if level > top:
        return 
    else:
        try:
            for child in general_categories(synset_id):
                l.append((child,level))
                generalization(child,top,l,level+1)
            return l
        except:
            return 
def concretization(page,top,max_expand,l=[],level=1):
    if level > top:
        return 
    else:
        try:
            for _,child in relevant_links(page,max_expand):
                l.append((child,level))
                concretization(child,top,max_expand,l,level+1)
            return l
        except:
            return []
    
class Concept():
    """Contains all the texts associated with a concept,
        each with an associated level of specificity"""
    def __init__(self,synset_id,pos,depth_up,depth_down):
        self.synset_id = synset_id
        self.depth_up,self.depth_down = depth_up,depth_down
        self.page = wiki_page(synset_id)
        self.pages = []
        
        if pos is "NOUN": #standard text mining
            #generalization
            for s_id,level in generalization(synset_id,depth_up):
                synset_page = wiki_page(s_id)
                if synset_page != None and synset_page.exists():
                    self.pages.append((synset_page,level))
            
            #concretization
            max_expand = int(np.ceil(np.power(len(self.pages),1/depth_down)))
            #for page,level in concretization(self.page,depth_down,max_expand):
            self.pages += [(link[1],-1) for link in relevant_links(self.page,len(self.pages))]
                
                
c = Concept( "bn:00005054n ","NOUN",1,1) #apple inc.         

print(c.pages)
# Out:
# [(Candy apple (id: 1127111, ns: 0), 1), (Pome (id: 311906, ns: 0), 1), (Apple juice (id: 454875, ns: 0), 1), (Stack cake (id: 2811212, ns: 0), 1), (Apple crisp (id: 1510907, ns: 0), 1), (Tarte Tatin (id: 523464, ns: 0), 1), (Apple strudel (id: 1191678, ns: 0), 1), (Apple soup (id: 25980154, ns: 0), 1), (Jewish apple cake (id: 30083318, ns: 0), 1), (Apfelküchle (id: 50347020, ns: 0), 1), (Cholera (food) (id: 39974802, ns: 0), 1), (Apple butter (id: 1595175, ns: 0), 1), (Žemlovka (id: 37552583, ns: 0), 1), (Vitréais (id: 46197603, ns: 0), 1), (Fruit (id: ??, ns: 0), -1), (Fruit tree (id: ??, ns: 0), -1), (Cultivar (id: ??, ns: 0), -1), (Asia (id: ??, ns: 0), -1), (Europe (id: ??, ns: 0), -1), (Golden apple (id: ??, ns: 0), -1), (Plant (id: ??, ns: 0), -1), (Apple juice (id: ??, ns: 0), -1), (Apple picking (id: ??, ns: 0), -1), (Fruit picking (id: ??, ns: 0), -1), (China (id: ??, ns: 0), -1), (United States (id: ??, ns: 0), -1), (Apple cider (id: ??, ns: 0), -1), (Cider apple (id: ??, ns: 0), -1)]

# %% [markdown]
# ### Article-Article distance

# %%
import sys
# %matplotlib notebook
from matplotlib import pyplot as plt
page1 = wiki.page("")
m1,d1 = fit_model(set_relevance(*stem_text(page1.text,title=page1.title.lower())))
page2 = wiki.page("")
m2,d2 = fit_model(set_relevance(*stem_text(page2.text,title=page2.title.lower())))
("appl","NOUN") in d2
# Out:
# banana
# apple
# False

# %%
s1 = [key for key in d1 if key in d2]
print(len(s1))
s1 = sorted(s1,key=lambda k: (d1[k]["relevance"]*d2[k]["relevance"])/(1+abs(d1[k]["relevance"]-d2[k]["relevance"]
)),reverse=True)
vals = np.array([(d1[k]["relevance"]*d2[k]["relevance"])/(1+abs(d1[k]["relevance"]-d2[k]["relevance"])) for k in s1])
vals = vals[vals>0]
diff = np.abs(np.diff(vals))
#top = diff / np.array(vals[:-1])
x = np.argmax(diff<0.001*diff[0])
#x=40
X = np.array([d1[x]["pos"] for x in s1[:x+1]]) #/len(d1)
Y = np.array([d2[x]["pos"] for x in s1[:x+1]]) #/len(d2)
#print(max(c1,c2))

for l in s1[:x]:
    print(l,d1[l]["pos"],d2[l]["pos"])
v1 = np.zeros(2) 
v = np.array([np.mean(X),np.mean(Y)])
print(np.linalg.norm(v1-v))
print(x,len(vals))
#plt.scatter(X,Y)
#plt.scatter(np.mean(X),np.mean(Y),color='r')
#plt.show
plt.plot(vals)
plt.show
# Out:
# 436
# ('fruit', 'NOUN') 0 0
# ('cultivar', 'NOUN') 1 2
# ('includ', 'VERB') 6 3
# ('produc', 'VERB') 2 13
# ('grow', 'VERB') 11 6
# ('plant', 'NOUN') 3 23
# 10.490034143249039
# 6 384
# <img src="data:image/png;base64,..." width="640">
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
from time import time
def aa_distance(d1,d2):
    t2 = time()
    if d1 is None or d2 is None:
        return np.inf
    s1 = [(k,(d1[k]["relevance"]*d2[k]["relevance"])/(1+abs(d1[k]["relevance"]-d2[k]["relevance"]))) for k in d1 if k in d2]
    if len(s1) == 0:
        return np.inf
    if len(s1) == 1:
        return np.linalg.norm(np.array([d1[s1[0]]["pos"],d2[s1[0]]["pos"]]))
    s1,vals = zip(*sorted(s1,key=lambda it: it[1],reverse=True))
    #print(s1)
    t3 = time()
    vals = np.array([(d1[k]["relevance"]*d2[k]["relevance"])/(1+abs(d1[k]["relevance"]-d2[k]["relevance"])) for k in s1])
    vals = vals[vals>0]
    diff = np.abs(np.diff(vals))
    if len(diff) == 0:
        return np.inf
    x = np.argmax(diff<0.001*diff[0])
    X,Y = zip(*[(d1[y]["pos"],d2[y]["pos"]) for y in s1[:x+1]]) #/len(d1)
    n = len(X)
    #print(X,Y)
    #v = np.array([(np.sum(X)-n*(n-1))/n,(np.sum(Y)-n*(n-1))/n])
    #print(t3-t2)
    v = np.array(np.mean(np.array(X)/len(d1)),np.mean(np.array(Y)/len(d2)))
    return np.linalg.norm(v)


    
page = wiki.page("Steve Jobs") 
concept_d = set_relevance(*stem_text(c.page.text,title=c.page.title.lower()),sort=True)
concept_page = set_relevance(*stem_text(page.text,title=page.title.lower()),sort=True)
distances = {}
for p,level in c.pages:
    t1 = time()
    d2 = set_relevance(*stem_text(p.text,title=p.title.lower()),sort=True)
    distances[p] = (aa_distance(concept_d,d2),d2)
    print(time()-t1)
m_distances = sorted(distances.keys(),key=lambda k: distances[k][0])
min(np.array([aa_distance(distances[p][1],concept_page)*((m_distances.index(p)+1)/len(distances)) for p,level in c.pages]))
# Out:
# 0.07688283920288086
# 0.05190610885620117
# 0.10362887382507324
# 0.04845380783081055
# 0.09060192108154297
# 0.09475398063659668
# 0.08419489860534668
# 0.022555828094482422
# 0.02152705192565918
# 0.08040976524353027
# 0.02557682991027832
# 0.41231584548950195
# 0.026500701904296875
# 0.014210224151611328
# 0.4018211364746094
# 0.04622220993041992
# 0.40616703033447266
# 1.0262870788574219
# 1.7621493339538574
# 0.24219417572021484
# 0.891624927520752
# 0.10608315467834473
# 0.05880379676818848
# 0.058653831481933594
# 1.8964848518371582
# 1.7791810035705566
# 0.18165302276611328
# 0.3946380615234375
# 0.0006495158154830034

# %% [markdown]
# # playground

# %%
page1 = wiki.page("Banana")
page2 = wiki.page("Apple")
d1 = set_relevance(*stem_text(page1.text,title=page1.title.lower()),sort=True)
d2 = set_relevance(*stem_text(page2.text,title=page2.title.lower()),sort=True)
aa_distance(d1,d2)
#d1
# Out:
# (('fruit', 'NOUN'), ('cultivar', 'NOUN'), ('includ', 'VERB'), ('produc', 'VERB'), ('grow', 'VERB'), ('plant', 'NOUN'), ('product', 'NOUN'), ('asia', 'PROPN'), ('cultiv', 'VERB'), ('cultiv', 'NOUN'), ('time', 'NOUN'), ('europ', 'PROPN'), ('diseas', 'NOUN'), ('wild', 'ADJ'), ('high', 'ADJ'), ('call', 'VERB'), ('dessert', 'NOUN'), ('varieti', 'NOUN'), ('skin', 'NOUN'), ('food', 'NOUN'), ('develop', 'VERB'), ('speci', 'NOUN'), ('caus', 'VERB'), ('grown', 'VERB'), ('centuri', 'NOUN'), ('east', 'PROPN'), ('cook', 'VERB'), ('seed', 'NOUN'), ('larg', 'ADJ'), ('commerci', 'ADJ'), ('year', 'NOUN'), ('leav', 'NOUN'), ('color', 'NOUN'), ('common', 'ADJ'), ('local', 'ADJ'), ('occur', 'VERB'), ('allow', 'VERB'), ('group', 'NOUN'), ('america', 'PROPN'), ('unit', 'PROPN'), ('state', 'PROPN'), ('modern', 'ADJ'), ('raw', 'ADJ'), ('north', 'PROPN'), ('genet', 'ADJ'), ('yellow', 'ADJ'), ('low', 'ADJ'), ('consid', 'VERB'), ('control', 'VERB'), ('market', 'NOUN'), ('rang', 'NOUN'), ('small', 'ADJ'), ('fresh', 'ADJ'), ('china', 'PROPN'), ('earli', 'ADJ'), ('spread', 'VERB'), ('popul', 'NOUN'), ('part', 'NOUN'), ('characterist', 'NOUN'), ('crop', 'NOUN'), ('number', 'NOUN'), ('consumpt', 'NOUN'), ('long', 'ADJ'), ('introduc', 'VERB'), ('tree', 'NOUN'), ('ripen', 'VERB'), ('produc', 'NOUN'), ('vari', 'VERB'), ('farmer', 'NOUN'), ('pest', 'NOUN'), ('sweet', 'ADJ'), ('transport', 'NOUN'), ('size', 'NOUN'), ('deriv', 'VERB'), ('eaten', 'VERB'), ('popular', 'ADJ'), ('water', 'NOUN'), ('appear', 'VERB'), ('area', 'NOUN'), ('farm', 'NOUN'), ('exist', 'VERB'), ('origin', 'ADJ'), ('gene', 'NOUN'), ('tast', 'NOUN'), ('late', 'ADJ'), ('turn', 'VERB'), ('resist', 'NOUN'), ('thought', 'VERB'), ('central', 'PROPN'), ('day', 'NOUN'), ('life', 'NOUN'), ('flavor', 'NOUN'), ('brown', 'ADJ'), ('consum', 'VERB'), ('today', 'NOUN'), ('cook', 'NOUN'), ('textur', 'NOUN'), ('ethylen', 'NOUN'), ('hybrid', 'NOUN'), ('depend', 'VERB'), ('make', 'VERB'), ('condit', 'NOUN'), ('center', 'NOUN'), ('ship', 'NOUN'), ('strain', 'NOUN'), ('method', 'NOUN'), ('term', 'NOUN'), ('storag', 'NOUN'), ('root', 'NOUN'), ('site', 'NOUN'), ('tabl', 'NOUN'), ('triploid', 'ADJ'), ('dri', 'VERB'), ('soft', 'ADJ'), ('bake', 'VERB'), ('word', 'NOUN'), ('pink', 'ADJ'), ('qualiti', 'NOUN'), ('recogn', 'VERB'), ('shoot', 'NOUN'), ('contribut', 'VERB'), ('bce', 'PROPN'), ('flower', 'NOUN'), ('flower', 'VERB'), ('wide', 'ADJ'), ('grower', 'NOUN'), ('amount', 'NOUN'), ('ft', 'NOUN'), ('suscept', 'ADJ'), ('prevent', 'VERB'), ('pick', 'VERB'), ('plant', 'VERB'), ('form', 'VERB'), ('level', 'NOUN'), ('difficult', 'ADJ'), ('dish', 'NOUN'), ('american', 'ADJ'), ('major', 'ADJ'), ('origin', 'VERB'), ('evid', 'NOUN'), ('domest', 'VERB'), ('peopl', 'NOUN'), ('group', 'PROPN'), ('brought', 'VERB'), ('exampl', 'NOUN'), ('will', 'VERB'), ('climat', 'NOUN'), ('tonn', 'NOUN'), ('sugar', 'NOUN'), ('held', 'VERB'), ('true', 'ADJ'), ('ancient', 'ADJ'), ('concentr', 'NOUN'), ('berri', 'NOUN'), ('fruit', 'PROPN'), ('higher', 'ADJ'), ('race', 'NOUN'), ('harvest', 'VERB'), ('collect', 'NOUN'), ('content', 'NOUN'), ('infloresc', 'NOUN'), ('fertil', 'NOUN'), ('form', 'NOUN'), ('countri', 'NOUN'), ('plantat', 'NOUN'), ('region', 'NOUN'), ('green', 'ADJ'), ('edibl', 'ADJ'), ('genus', 'NOUN'), ('process', 'NOUN'), ('soil', 'NOUN'), ('natur', 'ADJ'), ('tradit', 'ADJ'), ('harvest', 'NOUN'), ('fiber', 'NOUN'), ('refer', 'VERB'), ('origin', 'NOUN'), ('fungus', 'NOUN'), ('lead', 'VERB'), ('ripe', 'ADJ'), ('descript', 'NOUN'), ('carri', 'VERB'), ('describ', 'VERB'), ('black', 'ADJ'), ('sale', 'NOUN'), ('refriger', 'NOUN'), ('human', 'ADJ'), ('°', 'NOUN'), ('identifi', 'VERB'), ('total', 'ADJ'), ('treat', 'VERB'), ('problem', 'NOUN'), ('juic', 'NOUN'), ('requir', 'VERB'), ('languag', 'NOUN'), ('hand', 'NOUN'), ('stem', 'NOUN'), ('dwarf', 'PROPN'), ('univers', 'PROPN'), ('recommend', 'VERB'), ('break', 'VERB'), ('carbon', 'NOUN'), ('provid', 'VERB'), ('desir', 'ADJ'), ('unviabl', 'ADJ'), ('serv', 'VERB'), ('name', 'NOUN'), ('veget', 'NOU ...
# (0, 2, 6, 1, 10, 3, 18, 8, 15, 9, 42, 24, 49, 13, 68, 61, 11, 34, 17, 7, 85, 19, 47, 41, 114, 70) (0, 2, 3, 14, 6, 23, 16, 20, 18, 21, 7, 22, 11, 35, 10, 13, 53, 34, 52, 81, 9, 63, 39, 46, 8, 31)
# 4.795368821079095

# %%
def relevance(word,text_len,chunk_size=100): #AQUI TENEMOS EL CUELLO DE BOTELLA
    """
    Returns word relevance (probability of being in a randomly 
    positioned block of a fixed size).
    @Params:
        - word:  entry of stem_dict
        - text_len: text size (returned by stem_text())
        - chunk_size: block size, fixed
    """
    L = 0
    v = np.array(word["occurr"])
    if len(v) < 2:
        return 1/(text_len-chunk_size)
    #occ = v[(v>chunk_size)&(v<text_len-chunk_size)]
    v = v[v<text_len]
    occ = np.diff(v)
    for i,o in enumerate(occ):
        if o > chunk_size:
            if v[i] < chunk_size:
                L += v[i]
            elif text_len - chunk_size < v[i]:
                L += text_len - v[i]
            else:
                L+= chunk_size
        else:
            L += o
    #last one
    if len(v) > 0:
        if v[-1] < chunk_size:
            L += v[-1]
        elif text_len - chunk_size < v[-1]:
            L += text_len - v[-1]
        else:
            L += chunk_size
        #print(L)
        return (L)/(text_len-chunk_size)
    else:
        return 0
    
def relevance2(word,text_len,chunk_size=100): #AQUI TENEMOS EL CUELLO DE BOTELLA
    """
    Returns word relevance (probability of being in a randomly 
    positioned block of a fixed size).
    @Params:
        - word:  entry of stem_dict
        - text_len: text size (returned by stem_text())
        - chunk_size: block size, fixed
    """
    L = []
    for i in range(chunk_size,text_len,1):
        added = False
        for occ in word["occurr"]:
            if occ > i - chunk_size and occ <= i:
                L.append(1)
                added = True
                break
        if not added:
                L.append(0)
    #print("SUMA",np.sum(L),"LOng",len(L))
    return np.mean(L)    
    
    
page1 = wiki.page("Computer")
d,text_len,text = stem_text(page1.text,title=page1.title.lower())
n_chunks = int(text_len/average_sentence_size(text))
d["caca"] = {'occurr':[1,45]}
word = d["caca"]
print(relevance2(word,text_len,n_chunks))
relevance(word,text_len,n_chunks)
# Out:
# 0.027131782945736434
# 0.027131782945736434

# %%
page1 = wiki.page("computer")
t1 = time()
v = stem_text(page1.text,title=page1.title.lower())
t2 = time()
d1 = set_relevance(*v,sort=True)
t3 = time()
print(t2-t1,t3-t2)
# Out:
# 1.6718740463256836 0.013387918472290039

# %%
sorted(d1.keys(),key=lambda k: d1[k]["pos"])
# Out:
# [('devic', 'NOUN'),
#  ('memori', 'NOUN'),
#  ('machin', 'NOUN'),
#  ('modern', 'ADJ'),
#  ('number', 'NOUN'),
#  ('time', 'NOUN'),
#  ('data', 'NOUN'),
#  ('earli', 'ADJ'),
#  ('program', 'NOUN'),
#  ('instruct', 'NOUN'),
#  ('store', 'VERB'),
#  ('call', 'VERB'),
#  ('process', 'NOUN'),
#  ('thousand', 'NOUN'),
#  ('system', 'NOUN'),
#  ('perform', 'VERB'),
#  ('read', 'VERB'),
#  ('develop', 'VERB'),
#  ('design', 'VERB'),
#  ('design', 'NOUN'),
#  ('calcul', 'NOUN'),
#  ('built', 'VERB'),
#  ('oper', 'NOUN'),
#  ('includ', 'VERB'),
#  ('special', 'ADJ'),
#  ('control', 'NOUN'),
#  ('electron', 'ADJ'),
#  ('circuit', 'NOUN'),
#  ('exampl', 'NOUN'),
#  ('digit', 'ADJ'),
#  ('unit', 'NOUN'),
#  ('allow', 'VERB'),
#  ('work', 'VERB'),
#  ('arithmet', 'ADJ'),
#  ('applic', 'NOUN'),
#  ('oper', 'VERB'),
#  ('input', 'NOUN'),
#  ('cpu', 'NOUN'),
#  ('comput', 'NOUN'),
#  ('provid', 'VERB'),
#  ('type', 'NOUN'),
#  ('form', 'NOUN'),
#  ('programm', 'ADJ'),
#  ('power', 'NOUN'),
#  ('function', 'NOUN'),
#  ('output', 'NOUN'),
#  ('concept', 'NOUN'),
#  ('requir', 'VERB'),
#  ('complex', 'ADJ'),
#  ('develop', 'NOUN'),
#  ('task', 'NOUN'),
#  ('pc', 'NOUN'),
#  ('invent', 'VERB'),
#  ('problem', 'NOUN'),
#  ('mos', 'PROPN'),
#  ('repres', 'VERB'),
#  ('write', 'VERB'),
#  ('term', 'NOUN'),
#  ('keyboard', 'NOUN'),
#  ('year', 'NOUN'),
#  ('code', 'NOUN'),
#  ('inform', 'NOUN'),
#  ('speed', 'NOUN'),
#  ('general', 'ADJ'),
#  ('chip', 'NOUN'),
#  ('order', 'NOUN'),
#  ('complet', 'VERB'),
#  ('person', 'ADJ'),
#  ('solv', 'VERB'),
#  ('program', 'VERB'),
#  ('simpl', 'ADJ'),
#  ('execut', 'VERB'),
#  ('mechan', 'ADJ'),
#  ('logic', 'NOUN'),
#  ('architectur', 'NOUN'),
#  ('set', 'VERB'),
#  ('central', 'ADJ'),
#  ('set', 'NOUN'),
#  ('move', 'VERB'),
#  ('integr', 'ADJ'),
#  ('written', 'VERB'),
#  ('hardwar', 'NOUN'),
#  ('centuri', 'NOUN'),
#  ('work', 'NOUN'),
#  ('languag', 'NOUN'),
#  ('add', 'VERB'),
#  ('transistor', 'NOUN'),
#  ('chang', 'VERB'),
#  ('neumann', 'PROPN'),
#  ('ram', 'NOUN'),
#  ('john', 'PROPN'),
#  ('tube', 'NOUN'),
#  ('von', 'PROPN'),
#  ('analog', 'NOUN'),
#  ('second', 'ADJ'),
#  ('switch', 'NOUN'),
#  ('compon', 'NOUN'),
#  ('electr', 'ADJ'),
#  ('small', 'ADJ'),
#  ('capabl', 'ADJ'),
#  ('will', 'VERB'),
#  ('cell', 'NOUN'),
#  ('softwar', 'NOUN'),
#  ('result', 'NOUN'),
#  ('high', 'ADJ'),
#  ('integr', 'VERB'),
#  ('sequenc', 'NOUN'),
#  ('printer', 'NOUN'),
#  ('advanc', 'NOUN'),
#  ('binari', 'ADJ'),
#  ('addit', 'NOUN'),
#  ('enabl', 'VERB'),
#  ('element', 'NOUN'),
#  ('programm', 'NOUN'),
#  ('vacuum', 'NOUN'),
#  ('alu', 'PROPN'),
#  ('univers', 'PROPN'),
#  ('part', 'NOUN'),
#  ('execut', 'NOUN'),
#  ('locat', 'NOUN'),
#  ('engin', 'NOUN'),
#  ('word', 'NOUN'),
#  ('digit', 'PROPN'),
#  ('process', 'VERB'),
#  ('sophist', 'ADJ'),
#  ('practic', 'ADJ'),
#  ('singl', 'ADJ'),
#  ('short', 'ADJ'),
#  ('william', 'PROPN'),
#  ('regist', 'NOUN'),
#  ('program', 'PROPN'),
#  ('larg', 'ADJ'),
#  ('difficult', 'ADJ'),
#  ('jump', 'VERB'),
#  ('electron', 'NOUN'),
#  ('human', 'ADJ'),
#  ('purpos', 'NOUN'),
#  ('carri', 'VERB'),
#  ('turn', 'NOUN'),
#  ('main', 'ADJ'),
#  ('earliest', 'ADJ'),
#  ('signal', 'NOUN'),
#  ('trigonometri', 'NOUN'),
#  ('varieti', 'NOUN'),
#  ('calcul', 'VERB'),
#  ('propos', 'VERB'),
#  ('integr', 'NOUN'),
#  ('long', 'ADJ'),
#  ('extern', 'ADJ'),
#  ('root', 'NOUN'),
#  ('person', 'NOUN'),
#  ('divis', 'NOUN'),
#  ('microprocessor', 'NOUN'),
#  ('mechan', 'NOUN'),
#  ('numer', 'ADJ'),
#  ('mark', 'PROPN'),
#  ('turingcomplet', 'PROPN'),
#  ('cpus', 'NOUN'),
#  ('mosfet', 'PROPN'),
#  ('graphic', 'NOUN'),
#  ('uniqu', 'ADJ'),
#  ('circuitri', 'NOUN'),
#  ('day', 'NOUN'),
#  ('incorpor', 'VERB'),
#  ('squar', 'ADJ'),
#  ('messag', 'NOUN'),
#  ('wire', 'NOUN'),
#  ('method', 'NOUN'),
#  ('make', 'VERB'),
#  ('british', 'ADJ'),
#  ('basi', 'NOUN'),
#  ('faster', 'ADJ'),
#  ('creat', 'VERB'),
#  ('bit', 'NOUN'),
#  ('clock', 'NOUN'),
#  ('electron', 'PROPN'),
#  ('limit', 'VERB'),
#  ('comput', 'VERB'),
#  ('fundament', 'ADJ'),
#  ('compar', 'VERB'),
#  ('smaller', 'ADJ'),
#  ('billion', 'NOUN'),
#  ('display', 'VERB'),
#  ('term', 'VERB'),
#  ('depend', 'VERB'),
#  ('event', 'NOUN'),
#  ('return', 'VERB'),
#  ('rememb', 'VERB'),
#  ('bell', 'PROPN'),
#  ('lab', 'PROPN'),
#  ('reduc', 'VERB'),
#  ('analog', 'ADJ'),
#  ('level', 'NOUN'),
#  ('late', 'ADJ'),
#  ('basic', 'ADJ'),
#  ('ii', 'PROPN'),
#  ('ic', 'PROPN'),
#  ('rule', 'NOUN'),
#  ('lead', 'VERB'),
#  ('replac', 'VERB'),
#  ('logic', 'ADJ'),
#  ('complet', 'ADJ'),
#  ('20th', 'ADJ'),
#  ('card', 'NOUN'),
#  ('condit', 'ADJ'),
#  ('women', 'NOUN'),
#  ('1950s', 'NOUN'),
#  ('technolog', 'NOUN'),
#  ('need', 'VERB'),
#  ('1970s', 'NOUN'),
#  ('cpu', 'PROPN'),
#  ('babbag', 'PROPN'),
#  ('video', 'NOUN'),
#  ('build', 'VERB'),
#  ('semiconductor', 'NOUN'),
#  ('construct', 'NOUN'),
#  ('convert', 'VERB'),
#  ('run', 'VERB'),
#  ('featur', 'NOUN'),
#  ('modul', 'NOUN'),
#  ('ture', 'PROPN'),
#  ('laptop', 'NOUN'),
#  ('war', 'PROPN'),
#  ('aid', 'VERB'),
#  ('manual', 'ADJ'),
#  ('assembl', 'NOUN'),
#  ('produc', 'VERB'),
#  ('techniqu', 'NOUN'),
#  ('hundr', 'NOUN'),
#  ('consist', 'VERB'),
#  ('compil', 'NOUN'),
#  ('rom', 'NOUN'),
#  ('smartphon', 'NOUN'),
#  ('bc', 'PROPN'),
#  ('hand', 'NOUN'),
#  ('io', 'PROPN'),
#  ('list', 'NOUN'),
#  ('case', 'NOUN'),
#  ('univers', 'ADJ'),
#  ('base', 'VERB'),
#  ('place', 'NOUN'),
#  ('support', 'VERB'),
#  ('intervent', 'NOUN'),
#  ('storedprogram', 'PROPN'),
#  ('valv', 'NOUN'),
#  ('network', 'NOUN'),
#  ('turn', 'VERB'),
#  ('byte', 'NOUN'),
#  ('differenti', 'ADJ'),
#  ('earlier', 'ADJ'),
#  ('group', 'NOUN'),
#  ('slide', 'NOUN'),
#  ('commerci', 'ADJ'),
#  ('multipl', 'NOUN'),
#  ('relay', 'NOUN'),
#  ('thomson', 'PROPN'),
#  ('refer', 'VERB'),
#  ('mous', 'NOUN'),
#  ('boolean', 'ADJ'),
#  ('analyz', 'NOUN'),
#  ('punch', 'VERB'),
#  ('tablet', 'NOUN'),
#  ('atalla', 'PROPN'),
#  ('scale', 'NOUN'),
#  ('eniac', 'NOUN'),
#  ('moham', 'PROPN'),
#  ('torqu', 'NOUN'),
#  ('cach', 'NOUN'),
#  ('resourc', 'NOUN'),
#  ('navig', 'NOUN'),
#  ('exchang', 'NOUN'),
#  ('kahng', 'PROPN'),
#  ('step', 'NOUN'),
#  ('tabl', 'NOUN'),
#  ('error', 'NOUN'),
#  ('electromechan', 'ADJ'),
#  ('deliv', 'VERB'),
#  ('harvard', 'PROPN'),
#  ('command', 'NOUN'),
#  ('instruct', 'VERB'),
#  ('silicon', 'NOUN'),
#  ('server', 'NOUN'),
#  ('desktop', 'NOUN'),
#  ('screen', 'NOUN'),
#  ('inputoutput', 'NOUN'),
#  ('book', 'NOUN'),
#  ('english', 'ADJ'),
#  ('usag', 'NOUN'),
#  ('continu', 'VERB'),
#  ('period', 'NOUN'),
#  ('indic', 'VERB'),
#  ('theoret', 'ADJ'),
#  ('histori', 'NOUN'),
#  ('item', 'NOUN'),
#  ('complex', 'NOUN'),
#  ('construct', 'VERB'),
#  ('attribut', 'VERB'),
#  ('kind', 'NOUN'),
#  ('proport', 'NOUN'),
#  ('area', 'NOUN'),
#  ('handoper', 'VERB'),
#  ('perform', 'NOUN'),
#  ('routin', 'ADJ'),
#  ('distanc', 'NOUN'),
#  ('aircraft', 'NOUN'),
#  ('switch', 'VERB'),
#  ('intern', 'ADJ'),
#  ('letter', 'NOUN'),
#  ('track', 'NOUN'),
#  ('length', 'NOUN'),
#  ('sir', 'PROPN'),
#  ('great', 'ADJ'),
#  ('analys', 'NOUN'),
#  ('equat', 'NOUN'),
#  ('wheelanddisc', 'PROPN'),
#  ('lord', 'PROPN'),
#  ('kelvin', 'PROPN'),
#  ('limit', 'ADJ'),
#  ('drove', 'VERB'),
#  ('amplifi', 'NOUN'),
#  ('start', 'VERB'),
#  ('vannevar', 'PROPN'),
#  ('bush', 'PROPN'),
#  ('charl', 'PROPN'),
#  ('consid', 'VERB'),
#  ('realiz', 'VERB'),
#  ('flow', 'NOUN'),
#  ('branch', 'NOUN'),
#  ('loop', 'NOUN'),
#  ('generalpurpos', 'NOUN'),
#  ('describ', 'VERB'),
#  ('project', 'NOUN'),
#  ('version', 'NOUN'),
#  ('analog', 'PROPN'),
#  ('half', 'NOUN'),
#  ('met', 'VERB'),
#  ('direct', 'ADJ'),
#  ('lack', 'VERB'),
#  ('success', 'NOUN'),
#  ('float', 'VERB'),
#  ('point', 'NOUN'),
#  ('easier', 'ADJ'),
#  ('reliabl', 'ADJ'),
#  ('extend', 'VERB'),
#  ('began', 'VERB'),
#  ('experiment', 'ADJ'),
#  ('capacitor', 'NOUN'),
#  ('fix', 'VERB'),
#  ('drum', 'NOUN'),
#  ('achiev', 'VERB'),
#  ('break', 'VERB'),
#  ('help', 'NOUN'),
#  ('highlevel', 'ADJ'),
#  ('colleagu', 'NOUN'),
#  ('speed', 'VERB'),
#  ('integr', 'PROPN'),
#  ('defin', 'VERB'),
#  ('state', 'NOUN'),
#  ('cabl', 'NOUN'),
#  ('plug', 'NOUN'),
#  ('multipli', 'VERB'),
#  ('object', 'NOUN'),
#  ('storag', 'NOUN'),
#  ('demonstr', 'VERB'),
#  ('generat', 'NOUN'),
#  ('life', 'NOUN'),
#  ('team', 'NOUN'),
#  ('distinct', 'NOUN'),
#  ('oxid', 'NOUN'),
#  ('dawon', 'PROPN'),
#  ('led', 'VERB'),
#  ('drive', 'VERB'),
#  ('descript', 'NOUN'),
#  ('initi', 'ADJ'),
#  ('materi', 'NOUN'),
#  ('hybrid', 'ADJ'),
#  ('true', 'ADJ'),
#  ('note', 'VERB'),
#  ('eas', 'NOUN'),
#  ('improv', 'VERB'),
#  ('power', 'ADJ'),
#  ('ibm', 'PROPN'),
#  ('market', 'NOUN'),
#  ('way', 'NOUN'),
#  ('physic', 'ADJ'),
#  ('trillion', 'NOUN'),
#  ('common', 'ADJ'),
#  ('requir', 'ADJ'),
#  ('ad', 'VERB'),
#  ('modifi', 'VERB'),
#  ('repeat', 'VERB'),
#  ('happen', 'VERB'),
#  ('separ', 'ADJ'),
#  ('simplest', 'ADJ'),
#  ('complic', 'ADJ'),
#  ('multipl', 'ADJ'),
#  ('processor', 'NOUN'),
#  ('view', 'VERB'),
#  ('slow', 'ADJ'),
#  ('princip', 'ADJ'),
#  ('firmwar', 'NOUN'),
#  ('typic', 'ADJ'),
#  ('press', 'VERB'),
#  ('mistak', 'NOUN'),
#  ('mice', 'NOUN'),
#  ('manchest', 'PROPN'),
#  ('respons', 'NOUN'),
#  ('packag', 'NOUN'),
#  ('tom', 'PROPN'),
#  ('kilburn', 'PROPN'),
#  ('monolith', 'ADJ'),
#  ('peripher', 'ADJ'),
#  ('predict', 'VERB'),
#  ('ic', 'NOUN'),
#  ('conceptu', 'VERB'),
#  ('target', 'NOUN'),
#  ('state', 'PROPN'),
#  ('fairchild', 'PROPN'),
#  ('semiconductor', 'PROPN'),
#  ('mosfet', 'NOUN'),
#  ('german', 'ADJ'),
#  ('pennsylvania', 'PROPN'),
#  ('calendar', 'NOUN'),
#  ('increas', 'VERB'),
#  ('robert', 'PROPN'),
#  ('size', 'NOUN'),
#  ('game', 'NOUN'),
#  ('revolut', 'NOUN'),
#  ('versatil', 'NOUN'),
#  ('bipolar', 'ADJ'),
#  ('junction', 'NOUN'),
#  ('massproduc', 'VERB'),
#  ('ad', 'NOUN'),
#  ('involv', 'VERB'),
#  ('microchip', 'NOUN'),
#  ('soc', 'PROPN'),
#  ('coin', 'NOUN'),
#  ('mobil', 'PROPN'),
#  ('devis', 'VERB'),
#  ('contain', 'VERB'),
#  ('user', 'NOUN'),
#  ('algorithm', 'NOUN'),
#  ('mobil', 'ADJ'),
#  ('automat', 'ADJ'),
#  ('counter', 'NOUN'),
#  ('larger', 'ADJ'),
#  ('loom', 'NOUN'),
#  ('portabl', 'NOUN'),
#  ('date', 'VERB'),
#  ('document', 'NOUN'),
#  ('drive', 'NOUN'),
#  ('tedious', 'ADJ'),
#  ('oper', 'ADJ'),
#  ('autom', 'VERB'),
#  ('alan', 'PROPN'),
#  ('paper', 'NOUN'),
#  ('disk', 'NOUN'),
#  ('hard', 'ADJ'),
#  ('abacus', 'NOUN'),
#  ('peopl', 'NOUN'),
#  ('aid', 'NOUN'),
#  ('establish', 'PROPN'),
#  ('colossus', 'PROPN'),
#  ('eniac', 'PROPN'),
#  ('wide', 'ADJ'),
#  ('present', 'VERB'),
#  ('compact', 'ADJ'),
#  ('conceiv', 'VERB'),
#  ('equal', 'ADJ'),
#  ('idea', 'NOUN'),
#  ('million', 'NOUN'),
#  ('dictionari', 'PROPN'),
#  ('translat', 'VERB'),
#  ('system', 'PROPN'),
#  ('internet', 'NOUN'),
#  ('noyc', 'PROPN'),
#  ('kilbi', 'PROPN'),
#  ('understand', 'VERB'),
#  ('transistor', 'ADJ'),
#  ('electromechan', 'PROPN'),
#  ('zuse', 'PROPN'),
#  ('decod', 'VERB'),
#  ('z3', 'NOUN'),
#  ('fabric', 'VERB'),
#  ('entir', 'ADJ'),
#  ('slice', 'NOUN'),
#  ('count', 'NOUN'),
#  ('federico', 'PROPN'),
#  ('faggin', 'PROPN'),
#  ('babi', 'PROPN'),
#  ('retain', 'VERB'),
#  ('bletchley', 'PROPN'),
#  ('park', 'PROPN'),
#  ('cube', 'NOUN'),
#  ('display', 'NOUN'),
#  ('squar', 'NOUN'),
#  ('attack', 'VERB'),
#  ('abū', 'PROPN'),
#  ('rayhān', 'PROPN'),
#  ('albīrūnī', 'PROPN'),
#  ('full', 'ADJ'),
#  ('antikythera', 'PROPN'),
#  ('advantag', 'NOUN'),
#  ('equip', 'NOUN'),
#  ('astronom', 'ADJ'),
#  ('jump', 'NOUN'),
#  ('pulley', 'NOUN'),
#  ('interrupt', 'NOUN'),
#  ('storedprogram', 'ADJ'),
#  ('doll', 'NOUN'),
#  ('astrolab', 'NOUN'),
#  ('onlin', 'PROPN'),
#  ('etymolog', 'PROPN'),
#  ('instrument', 'NOUN'),
#  ('jame', 'PROPN'),
#  ('rang', 'NOUN'),
#  ('analyt', 'ADJ'),
#  ('wait', 'VERB'),
#  ('desktop', 'PROPN'),
#  ('logarithm', 'NOUN'),
#  ('communic', 'NOUN'),
#  ('multitask', 'NOUN'),
#  ('control', 'PROPN'),
#  ('comput', 'ADJ'),
#  ('gearwheel', 'PROPN'),
#  ('slower', 'ADJ'),
#  ('flash', 'NOUN'),
#  ('follow', 'VERB'),
#  ('revolut', 'PROPN'),
#  ('abil', 'NOUN'),
#  ('circular', 'ADJ'),
#  ('intel', 'PROPN'),
#  ('selfalign', 'PROPN'),
#  ('gate', 'PROPN'),
#  ('opcod', 'NOUN'),
#  ('clay', 'NOUN'),
#  ('telephon', 'NOUN'),
#  ('shockley', 'PROPN'),
#  ('number', 'VERB'),
#  ('alus', 'NOUN'),
#  ('access', 'VERB'),
#  ('silicong', 'PROPN'),
#  ('button', 'NOUN'),
#  ('2000s', 'NOUN'),
#  ('grace', 'PROPN'),
#  ('harwel', 'PROPN'),
#  ('planar', 'ADJ'),
#  ('retriev', 'VERB'),
#  ('hopper', 'PROPN'),
#  ('suppli', 'VERB'),
#  ('pcs', 'NOUN'),
#  ('sic', 'NOUN'),
#  ('atanasoff', 'PROPN'),
#  ('ferranti', 'PROPN'),
#  ('batteri', 'NOUN'),
#  ('tower', 'PROPN'),
#  ('pc', 'PROPN'),
#  ('mk', 'PROPN'),
#  ('mnemon', 'NOUN'),
#  ('berri', 'PROPN'),
#  ('scientist', 'NOUN'),
#  ('greater', 'ADJ'),
#  ('peripher', 'NOUN'),
#  ('caus', 'VERB'),
#  ('portabl', 'ADJ'),
#  ('dummer', 'PROPN'),
#  ('automaton', 'NOUN'),
#  ('hold', 'VERB'),
#  ('major', 'ADJ'),
#  ('fund', 'VERB'),
#  ('unit', 'PROPN'),
#  ('meant', 'VERB'),
#  ('militari', 'ADJ'),
#  ('encrypt', 'NOUN'),
#  ('combin', 'VERB'),
#  ('principl', 'NOUN'),
#  ('store', 'NOUN'),
#  ('capabl', 'NOUN'),
#  ('standard', 'NOUN'),
#  ('activ', 'ADJ'),
#  ('generat', 'VERB'),
#  ('definit', 'NOUN'),
#  ('cellular', 'ADJ'),
#  ('phone', 'NOUN'),
#  ('gate', 'NOUN'),
#  ('regist', 'VERB'),
#  ('statement', 'NOUN'),
#  ('vector', 'NOUN'),
#  ('memori', 'PROPN'),
#  ('optic', 'ADJ'),
#  ('highspe', 'NOUN'),
#  ('tend', 'VERB'),
#  ('organ', 'NOUN'),
#  ('util', 'VERB'),
#  ('largescal', 'ADJ'),
#  ('onlin', 'ADJ'),
#  ('media', 'NOUN'),
#  ('distinguish', 'VERB'),
#  ('appli', 'VERB'),
#  ('individu', 'ADJ'),
#  ('fact', 'NOUN'),
#  ('abstract', 'ADJ'),
#  ('connect', 'VERB'),
#  ('solut', 'NOUN'),
#  ('pattern', 'NOUN'),
#  ('formal', 'ADJ'),
#  ('paradigm', 'NOUN'),
#  ('challeng', 'NOUN'),
#  ('academ', 'ADJ'),
#  ('industri', 'ADJ'),
#  ('bug', 'NOUN'),
#  ('benign', 'ADJ'),
#  ('cluster', 'NOUN'),
#  ('consum', 'NOUN'),
#  ('microwav', 'NOUN'),
#  ('oven', 'NOUN'),
#  ('remot', 'ADJ'),
#  ('factori', 'NOUN'),
#  ('robot', 'NOUN'),
#  ('ancient', 'ADJ'),
#  ('industri', 'PROPN'),
#  ('guid', 'VERB'),
#  ('1940s', 'NOUN'),
#  ('siliconbas', 'VERB'),
#  ('count', 'VERB'),
#  ('rapid', 'ADJ'),
#  ('pace', 'NOUN'),
#  ('moor', 'PROPN'),
#  ('law', 'NOUN'),
#  ('20th', 'NOUN'),
#  ('21st', 'ADJ'),
#  ('metaloxidesemiconductor', 'ADJ'),
#  ('joystick', 'NOUN'),
#  ('monitor', 'VERB'),
#  ('touchscreen', 'NOUN'),
#  ('sourc', 'NOUN'),
#  ('save', 'VERB'),
#  ('etymolog', 'NOUN'),
#  ('oxford', 'PROPN'),
#  ('english', 'PROPN'),
#  ('yong', 'PROPN'),
#  ('man', 'PROPN'),
#  ('glean', 'PROPN'),
#  ('writer', 'NOUN'),
#  ('richard', 'PROPN'),
#  ('braithwait', 'PROPN'),
#  ('haue', 'VERB'),
#  ('truest', 'ADJ'),
#  ('time', 'PROPN'),
#  ('best', 'ADJ'),
#  ('arithmetician', 'PROPN'),
#  ('euer', 'ADJ'),
#  ('breath', 'VERB'),
#  ('reduceth', 'VERB'),
#  ('thi', 'VERB'),
#  ('mean', 'NOUN'),
#  ('middl', 'NOUN'),
#  ('hire', 'VERB'),
#  ('paid', 'VERB'),
#  ('male', 'ADJ'),
#  ('counterpart', 'NOUN'),
#  ('attest', 'VERB'),
#  ('1640s', 'NOUN'),
#  ('mean', 'VERB'),
#  ('agent', 'NOUN'),
#  ('noun', 'NOUN'),
#  ('state', 'VERB'),
#  ('sens', 'NOUN'),
#  ('onetoon', 'NOUN'),
#  ('correspond', 'NOUN'),
#  ('finger', 'NOUN'),
#  ('talli', 'NOUN'),
#  ('stick', 'NOUN'),
#  ('record', 'NOUN'),
#  ('keep', 'NOUN'),
#  ('fertil', 'PROPN'),
#  ('crescent', 'PROPN'),
#  ('calculi', 'NOUN'),
#  ('sphere', 'NOUN'),
#  ('cone', 'NOUN'),
#  ('livestock', 'NOUN'),
#  ('grain', 'NOUN'),
#  ('seal', 'VERB'),
#  ('hollow', 'ADJ'),
#  ('unbak', 'ADJ'),
#  ('contain', 'NOUN'),
#  ('rod', 'NOUN'),
#  ('roman', 'ADJ'),
#  ('babylonia', 'PROPN'),
#  ('reckon', 'NOUN'),
#  ('board', 'NOUN'),
#  ('mediev', 'ADJ'),
#  ('european', 'ADJ'),
#  ('hous', 'NOUN'),
#  ('checker', 'ADJ'),
#  ('cloth', 'NOUN'),
#  ('marker', 'NOUN'),
#  ('sum', 'NOUN'),
#  ('money', 'NOUN'),
#  ('believ', 'VERB'),
#  ('derek', 'PROPN'),
#  ('de', 'PROPN'),
#  ('solla', 'PROPN'),
#  ('price', 'PROPN'),
#  ('posit', 'NOUN'),
#  ('discov', 'VERB'),
#  ('wreck', 'NOUN'),
#  ('greek', 'ADJ'),
#  ('island', 'NOUN'),
#  ('kythera', 'PROPN'),
#  ('crete', 'PROPN'),
#  ('compar', 'ADJ'),
#  ('reappear', 'VERB'),
#  ('measur', 'NOUN'),
#  ('planispher', 'NOUN'),
#  ('star', 'NOUN'),
#  ('chart', 'NOUN'),
#  ('11th', 'ADJ'),
#  ('hellenist', 'ADJ'),
#  ('1st', 'ADJ'),
#  ('2nd', 'ADJ'),
#  ('hipparchus', 'PROPN'),
#  ('combin', 'NOUN'),
#  ('planispher', 'PROPN'),
#  ('dioptra', 'PROPN'),
#  ('spheric', 'ADJ'),
#  ('astronomi', 'NOUN'),
#  ('abi', 'PROPN'),
#  ('bakr', 'PROPN'),
#  ('isfahan', 'PROPN'),
#  ('persia', 'PROPN'),
#  ('gear', 'VERB'),
#  ('lunisolar', 'ADJ'),
#  ('astrolab', 'PROPN'),
#  ('fixedwir', 'ADJ'),
#  ('knowledg', 'NOUN'),
#  ('gear', 'NOUN'),
#  ('train', 'NOUN'),
#  ('sector', 'NOUN'),
#  ('16th', 'ADJ'),
#  ('gunneri', 'NOUN'),
#  ('survey', 'NOUN'),
#  ('planimet', 'NOUN'),
#  ('close', 'ADJ'),
#  ('figur', 'NOUN'),
#  ('trace', 'VERB'),
#  ('linkag', 'NOUN'),
#  ('public', 'NOUN'),
#  ('progress', 'VERB'),
#  ('reciproc', 'NOUN'),
#  ('transcendent', 'ADJ'),
#  ('exponenti', 'NOUN'),
#  ('hyperbol', 'ADJ'),
#  ('quick', 'ADJ'),
#  ('e6b', 'NOUN'),
#  ('light', 'ADJ'),
#  ('1770s', 'NOUN'),
#  ('pierr', 'PROPN'),
#  ('jaquetdroz', 'PROPN'),
#  ('swiss', 'ADJ'),
#  ('watchmak', 'NOUN'),
#  ('quill', 'NOUN'),
#  ('pen', 'NOUN'),
#  ('wheel', 'NOUN'),
#  ('musé', 'PROPN'),
#  ('dart', 'PROPN'),
#  ('dhistoir', 'PROPN'),
#  ('neuchâtel', 'PROPN'),
#  ('switzerland', 'PROPN'),
#  ('mathematician', 'NOUN'),
#  ('giovanni', 'PROPN'),
#  ('plana', 'PROPN'),
#  ('perpetu', 'PROPN'),
#  ('calendar', 'PROPN'),
#  ('cylind', 'NOUN'),
#  ('perpetu', 'ADJ'),
#  ('keep', 'VERB'),
#  ('leap', 'NOUN'),
#  ('vari', 'VERB'),
#  ('tidepredict', 'NOUN'),
#  ('util', 'NOUN'),
#  ('shallow', 'ADJ'),
#  ('water', 'NOUN'),
#  ('tide', 'NOUN'),
#  ('discuss', 'VERB'),
#  ('stymi', 'VERB'),
#  ('ballanddisk', 'NOUN'),
#  ('graph', 'NOUN'),
#  ('1920s', 'NOUN'),
#  ('differenti', 'NOUN'),
#  ('polymath', 'NOUN'),
#  ('origin', 'VERB'),
#  ('father', 'NOUN'),
#  ('19th', 'ADJ'),
#  ('revolutionari', 'ADJ'),
#  ('differ', 'NOUN'),
#  ('navig', 'ADJ'),
#  ('analyt', 'PROPN'),
#  ('direct', 'VERB'),
#  ('jacquard', 'PROPN'),
#  ('curv', 'NOUN'),
#  ('plotter', 'NOUN'),
#  ('bell', 'NOUN'),
#  ('dissolv', 'VERB'),
#  ('decis', 'NOUN'),
#  ('govern', 'PROPN'),
#  ('ceas', 'VERB'),
#  ('failur', 'NOUN'),
#  ('polit', 'ADJ'),
#  ('financi', 'ADJ'),
#  ('difficulti', 'NOUN'),
#  ('desir', 'NOUN'),
#  ('son', 'NOUN'),
#  ('henri', 'PROPN'),
#  ('simplifi', 'VERB'),
#  ('mill', 'NOUN'),
#  ('success', 'ADJ'),
#  ('demonstr', 'NOUN'),
#  ('scientif', 'ADJ'),
#  ('model', 'NOUN'),
#  ('accuraci', 'NOUN'),
#  ('tidepredict', 'VERB'),
#  ('brother', 'NOUN'),
#  ('famous', 'ADJ'),
#  ('art', 'NOUN'),
#  ('reach', 'VERB'),
#  ('zenith', 'NOUN'),
#  ('hazen', 'PROPN'),
#  ('mit', 'PROPN'),
#  ('nieman', 'PROPN'),
#  ('dozen', 'NOUN'),
#  ('obsolesc', 'NOUN'),
#  ('obvious', 'ADJ'),
#  ('spell', 'VERB'),
#  ('remain', 'VERB'),
#  ('educ', 'NOUN'),
#  ('navi', 'PROPN'),
#  ('submarin', 'NOUN'),
#  ('torpedo', 'PROPN'),
#  ('data', 'PROPN'),
#  ('fire', 'VERB'),
#  ('torpedo', 'NOUN'),
#  ('countri', 'NOUN'),
#  ('low', 'ADJ'),
#  ('supersed', 'VERB'),
#  ('allelectr', 'ADJ'),
#  ('z2', 'NOUN'),
#  ('konrad', 'PROPN'),
#  ('implement', 'VERB'),
#  ('frequenc', 'NOUN'),
#  ('5–10', 'PROPN'),
#  ('hz', 'PROPN'),
#  ('film', 'NOUN'),
#  ('respect', 'NOUN'),
#  ('pioneer', 'VERB'),
#  ('hardertoimpl', 'PROPN'),
#  ('decim', 'ADJ'),
#  ('ture', 'VERB'),
#  ('equival', 'NOUN'),
#  ('tommi', 'PROPN'),
#  ('flower', 'PROPN'),
#  ('post', 'PROPN'),
#  ('offic', 'PROPN'),
#  ('station', 'PROPN'),
#  ('london', 'PROPN'),
#  ('1930s', 'NOUN'),
#  ('explor', 'VERB'),
#  ('portion', 'NOUN'),
#  ('vincent', 'PROPN'),
#  ('clifford', 'PROPN'),
#  ('iowa', 'PROPN'),
#  ('test', 'VERB'),
#  ('abc', 'PROPN'),
#  ('allelectron', 'ADJ'),
#  ('rotat', 'VERB'),
#  ('encrypt', 'VERB'),
#  ('enigma', 'PROPN'),
#  ('bomb', 'NOUN'),
#  ('crack', 'VERB'),
#  ('german', 'PROPN'),
#  ('lorenz', 'PROPN'),
#  ('sz', 'PROPN'),
#  ('armi', 'PROPN'),
#  ('max', 'PROPN'),
#  ('newman', 'PROPN'),
#  ('commiss', 'VERB'),
#  ('flower', 'NOUN'),
#  ('spent', 'VERB'),
#  ('month', 'NOUN'),
#  ('function', 'ADJ'),
#  ('test', 'NOUN'),
#  ('ship', 'VERB'),
#  ('papertap', 'NOUN'),
#  ('configur', 'VERB'),
#  ('colossi', 'PROPN'),
#  ('total', 'ADJ'),
#  ('thermion', 'ADJ'),
#  ('simpler', 'ADJ'),
#  ('decod', 'NOUN'),
#  ('numer', 'PROPN'),
#  ('flexibl', 'ADJ'),
#  ('patch', 'NOUN'),
#  ('cri', 'NOUN'),
#  ('reset', 'NOUN'),
#  ('girl', 'NOUN'),
#  ('subtract', 'VERB'),
#  ('divid', 'NOUN'),
#  ('direct', 'NOUN'),
#  ('mauch', 'PROPN'),
#  ('presper', 'PROPN'),
#  ('eckert', 'PROPN'),
#  ('last', 'VERB'),
#  ('huge', 'ADJ'),
#  ('weigh', 'VERB'),
#  ('ton', 'NOUN'),
#  ('kilowatt', 'NOUN'),
#  ('resistor', 'NOUN'),
#  ('inductor', 'NOUN'),
#  ('semin', 'ADJ'),
#  ('comput', 'PROPN'),
#  ('prove', 'VERB'),
#  ('tape', 'NOUN'),
#  ('acknowledg', 'VERB'),
#  ('studi', 'NOUN'),
#  ('theori', 'NOUN'),
#  ('limit', 'NOUN'),
#  ('impos', 'VERB'),
#  ('finit', 'ADJ'),
#  ('equival', 'ADJ'),
#  ('rewir', 'NOUN'),
#  ('restructur', 'NOUN'),
#  ('propos', 'NOUN'),
#  ('detail', 'VERB'),
#  ('laid', 'VERB'),
#  ('ture', 'NOUN'),
#  ('join', 'VERB'),
#  ('nation', 'PROPN'),
#  ('physic', 'PROPN'),
#  ('laboratori', 'PROPN'),
#  ('report', 'NOUN'),
#  ('calcul', 'PROPN'),
#  ('specif', 'NOUN'),
#  ('circul', 'VERB'),
#  ('draft', 'PROPN'),
#  ('report', 'PROPN'),
#  ('edvac', 'PROPN'),
#  ('victoria', 'PROPN'),
#  ('freder', 'PROPN'),
#  ('geoff', 'PROPN'),
#  ('tootil', 'PROPN'),
#  ('testb', 'NOUN'),
#  ('randomaccess', 'PROPN'),
#  ('primit', 'ADJ'),
#  ('essenti', 'ADJ'),
#  ('feasibl', 'NOUN'),
#  ('initi', 'VERB'),
#  ('univers', 'NOUN'),
#  ('usabl', 'ADJ'),
#  ('prototyp', 'NOUN'),
#  ('shell', 'PROPN'),
#  ('lab', 'NOUN'),
#  ('amsterdam', 'PROPN'),
#  ('director', 'NOUN'),
#  ('cater', 'NOUN'),
#  ('compani', 'NOUN'),
#  ('lyon', 'PROPN'),
#  ('compani', 'PROPN'),
#  ('decid', 'VERB'),
#  ('role', 'NOUN'),
#  ('promot', 'VERB'),
#  ('leo', 'PROPN'),
#  ('regular', 'ADJ'),
#  ('offic', 'NOUN'),
#  ('job', 'NOUN'),
#  ('fieldeffect', 'NOUN'),
#  ('julius', 'PROPN'),
#  ('edgar', 'PROPN'),
#  ('lilienfeld', 'PROPN'),
#  ('bardeen', 'PROPN'),
#  ('walter', 'PROPN'),
#  ('brattain', 'PROPN'),
#  ('pointcontact', 'ADJ'),
#  ('rise', 'NOUN'),
#  ('heat', 'NOUN'),
#  ('indefinit', 'ADJ'),
#  ('servic', 'NOUN'),
#  ('ten', 'NOUN'),
#  ('space', 'NOUN'),
#  ('bulki', 'ADJ'),
#  ('manufactur', 'VERB'),
#  ('massproduct', 'NOUN'),
#  ('specialis', 'ADJ'),
#  ('leadership', 'NOUN'),
#  ('transistoris', 'ADJ'),
#  ('khz', 'NOUN'),
#  ('waveform', 'NOUN'),
#  ('magnet', 'ADJ'),
#  ('cadet', 'PROPN'),
#  ('atom', 'PROPN'),
#  ('energi', 'PROPN'),
#  ...]

# %%
l = np.array([1,2])
np.argmax(l[l!=0])
# Out:
# 1
